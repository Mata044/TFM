# %%
def candidates(n):
    L=[]
    for r in prime_range(n):
        for s in prime_range(r):
            if (r+s).prime_to_m_part(2).is_prime() and (r-s).prime_to_m_part(2).is_prime():
                L.append((r,s))
    return L

# %%
R.<x>=QQ[x]
P=choice(candidates(10000));
r=P[0];s=P[1]
f=x*(x-r)*(x-s)*(x-(r+s))*(x-(r-s));
P
# Out:
# (9623, 6551)

# %%
code = f"""
R<x>:=PolynomialRing(Rationals());
E:=HyperellipticCurve({f});
E;
J:=Jacobian(E);
#TwoSelmerGroup(J);
"""
magma_free(code)
# Out:
# Hyperelliptic Curve defined by y^2 = x^5 - 35420*x^4 + 424011605*x^3 - 2016902998030*x^2 + 3132252289542144*x over Rational Field
# 512
